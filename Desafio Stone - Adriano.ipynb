# %% [markdown]
# Contexto:
#
# Você sabe o que é um c hargeback ? Você pode aprender mais sobre em:
# https://www.equals.com.br/chargeback-como-evitar/
# Como anexo a este documento, enviamos um conjunto de transações realizadas por um de
# nossos clientes de e-commerce que possui um alto índice de c hargebacks . Na Aba 1, você
# encontra a data e hora de cada transação, o valor da transação, o número do cartão de origem
# e um indicador se ela sofreu ou não chargeback . Na Aba 2, temos dados similares, porém sem
# o indicador de chargeback .
#
# Perguntas:
#
# (1) Qual é o comportamento transacional do cliente?
# (2) Qual o perfil das transações que retornaram chargeback?
# (3) Quais transações na Aba 2 potencialmente sofrerão chargeback? Qual método você usou
# para chegar nessa conclusão?
# (4) Se você pudesse propor regras para melhorar a operação deste cliente, o que você
# proporia? Explique para a gente qual o impacto (numérico) das regras propostas.

# %%
#importação de bibliotecas

import pandas as pd
import matplotlib.pyplot as plt
import numpy as np
import seaborn as sns

# %%
df1 = pd.read_excel('Dados - Desafio Stone.xlsx', sheet_name='Aba 1')

# %%
#Criação de uma coluna com o valor do dia da semana, sendo 0 igual a segunda-feira, e 6, domingo.

df1['Dia da Semana'] = df1['Dia'].dt.dayofweek

# %%
df1
# Out:
#              Dia      Hora   Valor            Cartão  CBK  Dia da Semana
# 0     2015-05-01  00:01:54   36.54  536518******2108  Não              4
# 1     2015-05-01  00:03:46   36.54  536518******2108  Não              4
# 2     2015-05-01  00:08:50   69.00  453211******1239  Não              4
# 3     2015-05-01  00:27:00  193.43  548827******1705  Não              4
# 4     2015-05-01  01:32:46  132.00  531681******9778  Não              4
# 5     2015-05-01  02:10:26  161.00  515117******4107  Não              4
# 6     2015-05-01  08:09:15  110.00  432032******9111  Não              4
# 7     2015-05-01  08:30:16  159.50  544540******7141  Não              4
# 8     2015-05-01  09:13:51  126.50  554906******0358  Sim              4
# 9     2015-05-01  09:15:28  126.50  554906******0358  Sim              4
# 10    2015-05-01  09:16:52  126.50  554906******0358  Sim              4
# 11    2015-05-01  09:21:35  126.50  498406******6424  Sim              4
# 12    2015-05-01  09:23:02  126.50  498406******6424  Sim              4
# 13    2015-05-01  09:24:24  126.50  498406******6424  Sim              4
# 14    2015-05-01  09:25:47  126.50  498406******6424  Sim              4
# 15    2015-05-01  09:26:56  126.50  498406******6424  Sim              4
# 16    2015-05-01  09:28:27  126.50  498406******6424  Sim              4
# 17    2015-05-01  09:29:39  126.50  498406******6424  Sim              4
# 18    2015-05-01  09:30:52  126.50  498406******6424  Sim              4
# 19    2015-05-01  09:39:05  478.50  544731******2070  Não              4
# 20    2015-05-01  09:48:03   69.00  490172******7732  Não              4
# 21    2015-05-01  09:56:32  104.50  548046******0300  Não              4
# 22    2015-05-01  10:46:50  104.50  529323******2426  Não              4
# 23    2015-05-01  11:02:19   77.00  498442******9816  Não              4
# 24    2015-05-01  11:06:34  110.00  459315******9531  Não              4
# 25    2015-05-01  11:07:01  440.00  490172******0164  Não              4
# 26    2015-05-01  11:08:58  429.00  519698******1487  Não              4
# 27    2015-05-01  11:14:13  144.00  515787******5800  Não              4
# 28    2015-05-01  11:15:57   24.00  400770******3306  Não              4
# 29    2015-05-01  11:41:42   66.00  539028******0547  Não              4
# ...          ...       ...     ...               ...  ...            ...
# 11098 2015-05-30  20:34:07   70.00  519698******3034  Não              5
# 11099 2015-05-30  20:38:01   40.00  549167******0062  Não              5
# 11100 2015-05-30  20:38:26   20.00  515590******6029  Não              5
# 11101 2015-05-30  20:43:38   10.00  490172******6656  Não              5
# 11102 2015-05-30  20:46:00  190.40  523284******1177  Não              5
# 11103 2015-05-30  21:07:56   86.27  453211******8506  Não              5
# 11104 2015-05-30  21:18:01   10.00  425850******8189  Não              5
# 11105 2015-05-30  21:28:06  112.00  514868******3567  Não              5
# 11106 2015-05-30  21:30:34  100.80  490172******6113  Não              5
# 11107 2015-05-30  21:37:43   25.00  422061******0255  Não              5
# 11108 2015-05-30  21:50:59  176.00  449137******8747  Não              5
# 11109 2015-05-30  21:51:31   70.00  459078******7874  Não              5
# 11110 2015-05-30  21:57:00  123.20  455184******5823  Não              5
# 11111 2015-05-30  22:09:08  448.00  548827******4309  Não              5
# 11112 2015-05-30  22:14:04  154.00  515590******6271  Não              5
# 11113 2015-05-30  22:15:48   77.00  540105******7589  Não              5
# 11114 2015-05-30  22:17:09  112.00  410863******3564  Não              5
# 11115 2015-05-30  22:19:07   20.00  403225******6696  Não              5
# 11116 2015-05-30  22:20:09  448.00  548827******4309  Não              5
# 11117 2015-05-30  22:35:38   73.34  498453******8476  Não              5
# 11118 2015-05-30  22:38:19  448.00  539614******3442  Sim              5
# 11119 2015-05-30  22:50:27   72.00  400770******1995  Não              5
# 11120 2015-05-30  22:55:35   33.00  482108******6016  Não              5
# 11121 2015-05-30  23:01:12   15.00  553636******0914  Não              5
# 11122 2015-05-30  23:06:38   10.00  518759******2179  Não              5
# 11123 2015-05-30  23:07:01   53.00  514868******7409  Não              5
# 11124 2015-05-30  23:08:47   15.00  439354******5281  Não              5
# 11125 2015-05-30  23:15:24   20.00  549167******1648  Não              5
# 11126 2015-05-30  23:17:41   70.00  518759******8384  Não              5
# 11127 2015-05-30  23:51:31   20.00  518759******0329  Não              5
#
# [11128 rows x 6 columns]

# %%
df1.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 11128 entries, 0 to 11127
# Data columns (total 6 columns):
# Dia              11128 non-null datetime64[ns]
# Hora             11128 non-null object
# Valor            11128 non-null float64
# Cartão           11128 non-null object
# CBK              11128 non-null object
# Dia da Semana    11128 non-null int64
# dtypes: datetime64[ns](1), float64(1), int64(1), object(3)
# memory usage: 521.7+ KB

# %%
#criação de uma nova coluna 'DataTime', no formato datetime. Em seguida, setada como índice do dataframe

df1['DateTime'] = pd.to_datetime(df1['Hora'].astype(str))
df1.set_index('DateTime',inplace=True)

# %%
#Filtragem das linhas que tiveram Chargeback

chargeback = df1[df1['CBK']=='Sim']

# %%
df1['Valor'].describe()
# Out:
# count    11128.000000
# mean       129.550076
# std        141.420554
# min          1.000000
# 25%         55.000000
# 50%         99.000000
# 75%        154.000000
# max       2920.000000
# Name: Valor, dtype: float64

# %%
chargeback['Valor'].describe()
# Out:
# count     572.000000
# mean      183.300455
# std       165.331552
# min        13.990000
# 25%        69.000000
# 50%       132.000000
# 75%       209.250000
# max      1012.000000
# Name: Valor, dtype: float64

# %%
#Filtragem das linhas que não tiveram chargeback

nao_chargeback = df1[df1['CBK']=='Não']

# %%
nao_chargeback['Valor'].describe()
# Out:
# count    10556.000000
# mean       126.637494
# std        139.426771
# min          1.000000
# 25%         55.000000
# 50%         99.000000
# 75%        154.000000
# max       2920.000000
# Name: Valor, dtype: float64

# %%
#Agrupamento das linhas de chargeback por hora (frequência de 1 hora)

chargeback.resample('H').count()
# Out:
#                      Dia  Hora  Valor  Cartão  CBK  Dia da Semana
# DateTime
# 2020-12-16 00:00:00   16    16     16      16   16             16
# 2020-12-16 01:00:00   11    11     11      11   11             11
# 2020-12-16 02:00:00    8     8      8       8    8              8
# 2020-12-16 03:00:00    6     6      6       6    6              6
# 2020-12-16 04:00:00    0     0      0       0    0              0
# 2020-12-16 05:00:00    1     1      1       1    1              1
# 2020-12-16 06:00:00   10    10     10      10   10             10
# 2020-12-16 07:00:00    0     0      0       0    0              0
# 2020-12-16 08:00:00    0     0      0       0    0              0
# 2020-12-16 09:00:00   15    15     15      15   15             15
# 2020-12-16 10:00:00    7     7      7       7    7              7
# 2020-12-16 11:00:00   28    28     28      28   28             28
# 2020-12-16 12:00:00   33    33     33      33   33             33
# 2020-12-16 13:00:00   32    32     32      32   32             32
# 2020-12-16 14:00:00   29    29     29      29   29             29
# 2020-12-16 15:00:00   69    69     69      69   69             69
# 2020-12-16 16:00:00   98    98     98      98   98             98
# 2020-12-16 17:00:00   42    42     42      42   42             42
# 2020-12-16 18:00:00   22    22     22      22   22             22
# 2020-12-16 19:00:00   37    37     37      37   37             37
# 2020-12-16 20:00:00   18    18     18      18   18             18
# 2020-12-16 21:00:00   21    21     21      21   21             21
# 2020-12-16 22:00:00   31    31     31      31   31             31
# 2020-12-16 23:00:00   38    38     38      38   38             38

# %%
hora_chargeback = chargeback['Dia'].resample('H').count()
hora_chargeback
# Out:
# DateTime
# 2020-12-16 00:00:00    16
# 2020-12-16 01:00:00    11
# 2020-12-16 02:00:00     8
# 2020-12-16 03:00:00     6
# 2020-12-16 04:00:00     0
# 2020-12-16 05:00:00     1
# 2020-12-16 06:00:00    10
# 2020-12-16 07:00:00     0
# 2020-12-16 08:00:00     0
# 2020-12-16 09:00:00    15
# 2020-12-16 10:00:00     7
# 2020-12-16 11:00:00    28
# 2020-12-16 12:00:00    33
# 2020-12-16 13:00:00    32
# 2020-12-16 14:00:00    29
# 2020-12-16 15:00:00    69
# 2020-12-16 16:00:00    98
# 2020-12-16 17:00:00    42
# 2020-12-16 18:00:00    22
# 2020-12-16 19:00:00    37
# 2020-12-16 20:00:00    18
# 2020-12-16 21:00:00    21
# 2020-12-16 22:00:00    31
# 2020-12-16 23:00:00    38
# Freq: H, Name: Dia, dtype: int64

# %%
#Divisão das linhas de não chargeback por hora (frequência de 1 hora)

hora_nao_chargeback = nao_chargeback['Dia'].resample('H').count()
hora_nao_chargeback
# Out:
# DateTime
# 2020-12-16 00:00:00    247
# 2020-12-16 01:00:00    117
# 2020-12-16 02:00:00     42
# 2020-12-16 03:00:00     20
# 2020-12-16 04:00:00     10
# 2020-12-16 05:00:00      4
# 2020-12-16 06:00:00     20
# 2020-12-16 07:00:00     79
# 2020-12-16 08:00:00    203
# 2020-12-16 09:00:00    364
# 2020-12-16 10:00:00    582
# 2020-12-16 11:00:00    606
# 2020-12-16 12:00:00    616
# 2020-12-16 13:00:00    731
# 2020-12-16 14:00:00    736
# 2020-12-16 15:00:00    708
# 2020-12-16 16:00:00    640
# 2020-12-16 17:00:00    718
# 2020-12-16 18:00:00    779
# 2020-12-16 19:00:00    796
# 2020-12-16 20:00:00    670
# 2020-12-16 21:00:00    695
# 2020-12-16 22:00:00    689
# 2020-12-16 23:00:00    484
# Freq: H, Name: Dia, dtype: int64

# %%
#Agrupamento do número de chargebacks por dia da semana

chargeback.groupby('Dia da Semana')['Dia'].count()
# Out:
# Dia da Semana
# 0     74
# 1     69
# 2     71
# 3     99
# 4    130
# 5    102
# 6     27
# Name: Dia, dtype: int64

# %%
#Agrupamento do valor médio de chargebacks por dia da semana

chargeback.groupby('Dia da Semana').mean()
# Out:
#                     Valor
# Dia da Semana
# 0              175.826486
# 1              155.674203
# 2              265.130563
# 3              140.800909
# 4              142.770385
# 5              230.269314
# 6              232.740741

# %%
#Agrupamento do número de não chargebacks por dia da semana

nao_chargeback.groupby('Dia da Semana')['Dia'].count()
# Out:
# Dia da Semana
# 0    1603
# 1    1409
# 2    1557
# 3    1891
# 4    2310
# 5    1211
# 6     575
# Name: Dia, dtype: int64

# %%
#Agrupamento do valor médio de não chargebacks por dia da semana

nao_chargeback.groupby('Dia da Semana').mean()
# Out:
#                     Valor
# Dia da Semana
# 0              163.604541
# 1              119.945224
# 2              122.707585
# 3              122.360851
# 4              125.203030
# 5              107.686515
# 6              110.360070

# %% [markdown]
# # Plotagem dos Dados

# %%
y = hora_chargeback
x = [x for x in range(24)]
fig, ax = plt.subplots(figsize=(16, 6))
ax.bar(x, y, tick_label = x)

ax.set(title = "Número de Chargebacks por Hora", xlabel = "Hora do Dia")
# Out:
# [Text(0.5,0,'Hora do Dia'), Text(0.5,1,'Número de Chargebacks por Hora')]

# %%
y = hora_nao_chargeback
x = [x for x in range(24)]
fig, ax = plt.subplots(figsize=(16, 6))
ax.bar(x, y, tick_label = x)

ax.set(title = "Número de Transações Não-Chargebacks por Hora", xlabel = "Hora do Dia")
# Out:
# [Text(0.5,0,'Hora do Dia'),
#  Text(0.5,1,'Número de Transações Não-Chargebacks por Hora')]

# %%
y = chargeback['Valor'].resample('H').mean()
x = [x for x in range(24)]
fig, ax = plt.subplots(figsize=(16, 6))
ax.bar(x, y, tick_label = x)

ax.set(title = "Valor Médio dos Chargebacks por Hora", xlabel = "Hora do Dia")
# Out:
# [Text(0.5,0,'Hora do Dia'), Text(0.5,1,'Valor dos Chargebacks por Hora')]

# %%
y = nao_chargeback['Valor'].resample('H').mean()
x = [x for x in range(24)]
fig, ax = plt.subplots(figsize=(16, 6))
ax.bar(x, y, tick_label = x)

ax.set(title = "Valor Médio dos Não Chargebacks por Hora", xlabel = "Hora do Dia")
# Out:
# [Text(0.5,0,'Hora do Dia'), Text(0.5,1,'Valor dos Não Chargebacks por Hora')]

# %%
# Numbers of pairs of bars you want
N = 24

# Data on X-axis

# Specify the values of blue bars (height)
blue_bar = chargeback['Valor'].resample('H').mean()
# Specify the values of orange bars (height)
orange_bar = nao_chargeback['Valor'].resample('H').mean()

# Position of bars on x-axis
ind = np.arange(N)

# Figure size
plt.figure(figsize=(12,6))

# Width of a bar 
width = 0.3       

# Plotting
plt.bar(ind, blue_bar , width, label='Valor dos Chargebacks')
plt.bar(ind + width, orange_bar, width, label='Valor dos Não Chargebacks')

plt.xlabel('Hora do Dia')
#plt.ylabel('Valor Médio')
plt.title('Valor Médio dos Chargebacks e Não Chargebacks por Hora do Dia')

# xticks()
# First argument - A list of positions at which ticks should be placed
# Second argument -  A list of labels to place at the given locations
x = [x for x in range(24)]
plt.xticks(ind + width / 2, x)

# Finding the best position for legends and putting it
plt.legend(loc='best')

# %%
fig = plt.figure(figsize =(10, 7)) 
plt.ylim(0, 500)
plt.boxplot(chargeback['Valor'], whis=1.5)
# Out:
# {'whiskers': [<matplotlib.lines.Line2D at 0x28f170dbeb8>,
#   <matplotlib.lines.Line2D at 0x28f170e72b0>],
#  'caps': [<matplotlib.lines.Line2D at 0x28f170e7748>,
#   <matplotlib.lines.Line2D at 0x28f170e7b70>],
#  'boxes': [<matplotlib.lines.Line2D at 0x28f170dbd68>],
#  'medians': [<matplotlib.lines.Line2D at 0x28f170f1400>],
#  'fliers': [<matplotlib.lines.Line2D at 0x28f170f1470>],
#  'means': []}

# %%
fig = plt.figure(figsize =(10, 7)) 
plt.ylim(0, 400)
plt.boxplot(nao_chargeback['Valor'], whis=1.5)
# Out:
# {'whiskers': [<matplotlib.lines.Line2D at 0x28f170fcf60>,
#   <matplotlib.lines.Line2D at 0x28f17142320>],
#  'caps': [<matplotlib.lines.Line2D at 0x28f17142390>,
#   <matplotlib.lines.Line2D at 0x28f171427b8>],
#  'boxes': [<matplotlib.lines.Line2D at 0x28f17137940>],
#  'medians': [<matplotlib.lines.Line2D at 0x28f17142be0>],
#  'fliers': [<matplotlib.lines.Line2D at 0x28f17149080>],
#  'means': []}

# %%
y = chargeback.groupby('Dia da Semana')['Dia'].count()
x = [x for x in range(7)]
fig, ax = plt.subplots(figsize=(16, 6))
ax.bar(x, y, tick_label = x)

ax.set(title = "Número de Chargebacks por Dia da Semana", xlabel = "Dia da Semana")
# Out:
# [Text(0.5,0,'Dia da Semana'),
#  Text(0.5,1,'Número de Chargebacks por Dia da Semana')]

# %%
y = nao_chargeback.groupby('Dia da Semana')['Dia'].count()
x = [x for x in range(7)]
fig, ax = plt.subplots(figsize=(16, 6))
ax.bar(x, y, tick_label = x)

ax.set(title = "Número de Transações Não Chargebacks por Dia da Semana", xlabel = "Dia da Semana")
# Out:
# [Text(0.5,0,'Dia da Semana'),
#  Text(0.5,1,'Número de Transações Não Chargebacks por Dia da Semana')]

# %%
# Numbers of pairs of bars you want
N = 7

# Data on X-axis

# Specify the values of blue bars (height)
blue_bar = chargeback.groupby('Dia da Semana')['Valor'].mean()
# Specify the values of orange bars (height)
orange_bar = nao_chargeback.groupby('Dia da Semana')['Valor'].mean()

# Position of bars on x-axis
ind = np.arange(N)

# Figure size
plt.figure(figsize=(12,6))

# Width of a bar 
width = 0.3       

# Plotting
plt.bar(ind, blue_bar , width, label='Valor dos Chargebacks')
plt.bar(ind + width, orange_bar, width, label='Valor dos Não Chargebacks')

plt.xlabel('Dia da Semana')
#plt.ylabel('Valor Médio')
plt.title('Valor Médio dos Chargebacks e Não Chargebacks por Dia da Semana')

# xticks()
# First argument - A list of positions at which ticks should be placed
# Second argument -  A list of labels to place at the given locations
x = [x for x in range(7)]
plt.xticks(ind + width / 2, x)

# Finding the best position for legends and putting it
plt.legend(loc='best')

# %% [markdown]
# As transações do tipo chargeback apresentam comportamentos distintos das outras transações.
#
# Em termos de hora do dia, as transações do tipo chargeback ocorrem mais acentuamente no horário das 15 às 17 horas.
#
# Em relação aos valores das transações, o valor médio das transações chargeback são maiores que as transações normais. Em especial, transações de chargeback muito tarde da noite e de madrugada possuem valores mais altos (como às 3 da manhã).
#
# Finalmente, para o dia da semana não é possível identificar um dia com um grande volume para se diferenciar os dois tipos de transações. Sexta-feira é o dia de maior volume de transações chargebacks ou não. No entanto, ao se analisar o valor médio das transações, quarta-feira, sábado e domingo apresentam um alto valor médio de transações do tipo chargeback.

# %% [markdown]
# # Parte 2 - Machine Learning

# %%
#leitura da aba 2, relativo aos dados sem informação de chargebacks

df2 = pd.read_excel('Dados - Desafio Stone.xlsx', sheet_name='Aba 2')

# %%
#Criação de uma coluna com o valor do dia da semana, sendo 0 igual a segunda-feira, e 6, domingo.

df2['Dia da Semana'] = df2['Dia'].dt.dayofweek

# %%
df2
# Out:
#              Dia      Hora    Valor            Cartão  CBK  Dia da Semana
# 0     2015-06-01  00:02:25   112.00  541555******5965  NaN              0
# 1     2015-06-01  00:30:45   112.00  406669******7350  NaN              0
# 2     2015-06-01  00:43:20    18.34  541187******4535  NaN              0
# 3     2015-06-01  00:46:46    55.00  554927******5629  NaN              0
# 4     2015-06-01  00:47:50    50.00  498407******2077  NaN              0
# 5     2015-06-01  00:48:51    50.00  498407******2077  NaN              0
# 6     2015-06-01  00:49:55    50.00  498407******2077  NaN              0
# 7     2015-06-01  00:51:08    50.00  498407******2077  NaN              0
# 8     2015-06-01  00:53:28   201.60  498407******2077  NaN              0
# 9     2015-06-01  00:54:39   201.60  498407******2077  NaN              0
# 10    2015-06-01  00:55:33   201.60  498407******2077  NaN              0
# 11    2015-06-01  01:03:31    53.60  540105******5422  NaN              0
# 12    2015-06-01  01:18:46   112.00  515894******8424  NaN              0
# 13    2015-06-01  01:28:28    88.00  453211******9596  NaN              0
# 14    2015-06-01  01:45:59   280.00  490172******5444  NaN              0
# 15    2015-06-01  02:26:37   134.40  554927******7779  NaN              0
# 16    2015-06-01  08:04:11  1100.00  548293******5170  NaN              0
# 17    2015-06-01  08:26:23    88.00  525631******5400  NaN              0
# 18    2015-06-01  09:01:54   115.00  400970******8593  NaN              0
# 19    2015-06-01  09:09:54    15.00  498401******1936  NaN              0
# 20    2015-06-01  09:15:46    89.60  490172******4684  NaN              0
# 21    2015-06-01  09:37:31    89.60  406669******8655  NaN              0
# 22    2015-06-01  09:38:37    24.00  548724******6893  NaN              0
# 23    2015-06-01  09:38:46    89.60  549167******1773  NaN              0
# 24    2015-06-01  09:49:12     5.00  415274******2113  NaN              0
# 25    2015-06-01  09:57:05    35.00  415274******2113  NaN              0
# 26    2015-06-01  10:04:40   182.69  490172******3768  NaN              0
# 27    2015-06-01  10:09:03    15.00  546479******4064  NaN              0
# 28    2015-06-01  10:09:27    99.00  409603******0510  NaN              0
# 11125  23:15:24   20.00    0              5
# 11126  23:17:41   70.00    0              5
# 11127  23:51:31   20.00    0              5
#
# [11128 rows x 4 columns]

# %%
#criação de um novo dataframe que agrupa os horários do dia em números (23:51:31 se torna 23, por exemplo). Desta forma, transforma os dados datetime.time em inteiros, permitindo a utilização nos modelos.

hora_dia = []

for i in range(len(df['Hora'])):
    hora_dia.append(df['Hora'][i].hour)
    
df_teste = pd.DataFrame(hora_dia, columns=['Hora do Dia'])

# %%
df_teste
# Out:
#        Hora do Dia
# 0                0
# 1                0
# 2                0
# 3                0
# 4                1
# 5                2
# 6                8
# 7                8
# 8                9
# 9                9
# 10               9
# 11               9
# 12               9
# 13               9
# 14               9
# 15               9
# 16               9
# 17               9
# 18               9
# 19               9
# 20               9
# 21               9
# 22              10
# 23              11
# 24              11
# 25              11
# 26              11
# 27              11
# 28              11
# 29              11
# ...            ...
# 11098           20
# 11099           20
# 11100           20
# 11101           20
# 11102           20
# 11103           21
# 11104           21
# 11105           21
# 11106           21
# 11107           21
# 11108           21
# 11109           21
# 11110           21
# 11111           22
# 11112           22
# 11113           22
# 11114           22
# 11115           22
# 11116           22
# 11117           22
# 11118           22
# 11119           22
# 11120           22
# 11121           23
# 11122           23
# 11123           23
# 11124           23
# 11125           23
# 11126           23
# 11127           23
#
# [11128 rows x 1 columns]

# %%
#junção dos dois dataframes, o original e o novo com as horas do dia.

df = pd.concat([df, df_teste], axis=1)

# %%
df
# Out:
#            Hora   Valor  CBK  Dia da Semana  Hora do Dia
# 0      00:01:54   36.54    0              4            0
# 1      00:03:46   36.54    0              4            0
# 2      00:08:50   69.00    0              4            0
# 3      00:27:00  193.43    0              4            0
# 4      01:32:46  132.00    0              4            1
# 5      02:10:26  161.00    0              4            2
# 6      08:09:15  110.00    0              4            8
# 7      08:30:16  159.50    0              4            8
# 8      09:13:51  126.50    1              4            9
# 9      09:15:28  126.50    1              4            9
# 10     09:16:52  126.50    1              4            9
# 11     09:21:35  126.50    1              4            9
# 12     09:23:02  126.50    1              4            9
# 13     09:24:24  126.50    1              4            9
# 14     09:25:47  126.50    1              4            9
# 15     09:26:56  126.50    1              4            9
# 16     09:28:27  126.50    1              4            9
# 17     09:29:39  126.50    1              4            9
# 18     09:30:52  126.50    1              4            9
# 19     09:39:05  478.50    0              4            9
# 20     09:48:03   69.00    0              4            9
# 21     09:56:32  104.50    0              4            9
# 22     10:46:50  104.50    0              4           10
# 23     11:02:19   77.00    0              4           11
# 24     11:06:34  110.00    0              4           11
# 25     11:07:01  440.00    0              4           11
# 26     11:08:58  429.00    0              4           11
# 27     11:14:13  144.00    0              4           11
# 28     11:15:57   24.00    0              4           11
# 29     11:41:42   66.00    0              4           11
# ...         ...     ...  ...            ...          ...
# 11098  20:34:07   70.00    0              5           20
# 11099  20:38:01   40.00    0              5           20
# 11100  20:38:26   20.00    0              5           20
# 11101  20:43:38   10.00    0              5           20
# 11102  20:46:00  190.40    0              5           20
# 11103  21:07:56   86.27    0              5           21
# 11104  21:18:01   10.00    0              5           21
# 11105  21:28:06  112.00    0              5           21
# 11106  21:30:34  100.80    0              5           21
# 11107  21:37:43   25.00    0              5           21
# 11108  21:50:59  176.00    0              5           21
# 11109  21:51:31   70.00    0              5           21
# 11110  21:57:00  123.20    0              5           21
# 11111  22:09:08  448.00    0              5           22
# 11112  22:14:04  154.00    0              5           22
# 11113  22:15:48   77.00    0              5           22
# 11114  22:17:09  112.00    0              5           22
# 11115  22:19:07   20.00    0              5           22
# 11116  22:20:09  448.00    0              5           22
# 11117  22:35:38   73.34    0              5           22
# 11118  22:38:19  448.00    1              5           22
# 11119  22:50:27   72.00    0              5           22
# 11120  22:55:35   33.00    0              5           22
# 11121  23:01:12   15.00    0              5           23
# 11122  23:06:38   10.00    0              5           23
# 11123  23:07:01   53.00    0              5           23
# 11124  23:08:47   15.00    0              5           23
# 11125  23:15:24   20.00    0              5           23
# 11126  23:17:41   70.00    0              5           23
# 11127  23:51:31   20.00    0              5           23
#
# [11128 rows x 5 columns]

# %%
#eliminação da coluna 'Hora'.

df.drop(['Hora'], axis=1, inplace=True)
df
# Out:
#         Valor  CBK  Dia da Semana  Hora do Dia
# 0       36.54    0              4            0
# 1       36.54    0              4            0
# 2       69.00    0              4            0
# 3      193.43    0              4            0
# 4      132.00    0              4            1
# 5      161.00    0              4            2
# 6      110.00    0              4            8
# 7      159.50    0              4            8
# 8      126.50    1              4            9
# 9      126.50    1              4            9
# 10     126.50    1              4            9
# 11     126.50    1              4            9
# 12     126.50    1              4            9
# 13     126.50    1              4            9
# 14     126.50    1              4            9
# 15     126.50    1              4            9
# 16     126.50    1              4            9
# 17     126.50    1              4            9
# 18     126.50    1              4            9
# 19     478.50    0              4            9
# 20      69.00    0              4            9
# 21     104.50    0              4            9
# 22     104.50    0              4           10
# 23      77.00    0              4           11
# 24     110.00    0              4           11
# 25     440.00    0              4           11
# 26     429.00    0              4           11
# 27     144.00    0              4           11
# 28      24.00    0              4           11
# 29      66.00    0              4           11
# ...       ...  ...            ...          ...
# 11098   70.00    0              5           20
# 11099   40.00    0              5           20
# 11100   20.00    0              5           20
# 11101   10.00    0              5           20
# 11102  190.40    0              5           20
# 11103   86.27    0              5           21
# 11104   10.00    0              5           21
# 11105  112.00    0              5           21
# 11106  100.80    0              5           21
# 11107   25.00    0              5           21
# 11108  176.00    0              5           21
# 11109   70.00    0              5           21
# 11110  123.20    0              5           21
# 11111  448.00    0              5           22
# 11112  154.00    0              5           22
# 11113   77.00    0              5           22
# 11114  112.00    0              5           22
# 11115   20.00    0              5           22
# 11116  448.00    0              5           22
# 11117   73.34    0              5           22
# 11118  448.00    1              5           22
# 11119   72.00    0              5           22
# 11120   33.00    0              5           22
# 11121   15.00    0              5           23
# 11122   10.00    0              5           23
# 11123   53.00    0              5           23
# 11124   15.00    0              5           23
# 11125   20.00    0              5           23
# 11126   70.00    0              5           23
# 11127   20.00    0              5           23
#
# [11128 rows x 4 columns]

# %%
from sklearn.model_selection import train_test_split

# %%
from sklearn.linear_model import LogisticRegression

# %%
x_train, x_test, y_train, y_test = train_test_split(df.drop('CBK', axis=1), df['CBK'], test_size=0.3)

# %%
logmodel = LogisticRegression()

# %%
logmodel.fit(x_train, y_train)
# Out:
# LogisticRegression(C=1.0, class_weight=None, dual=False, fit_intercept=True,
#           intercept_scaling=1, max_iter=100, multi_class='ovr', n_jobs=1,
#           penalty='l2', random_state=None, solver='liblinear', tol=0.0001,
#           verbose=0, warm_start=False)

# %%
predictions = logmodel.predict(x_test)

# %%
from sklearn.metrics import classification_report

# %%
print(classification_report(y_test, predictions))
# Out:
#              precision    recall  f1-score   support
#
#           0       0.95      1.00      0.97      3178
#           1       0.00      0.00      0.00       161
#
# avg / total       0.91      0.95      0.93      3339

# %%
from sklearn.metrics import confusion_matrix

# %%
print(confusion_matrix(y_test, predictions))
# Out:
# [[3176    2]
#  [ 161    0]]

# %%
from sklearn.tree import DecisionTreeClassifier

# %%
from sklearn.ensemble import RandomForestClassifier
# Out:
# C:\Users\adria\Anaconda3\lib\site-packages\sklearn\ensemble\weight_boosting.py:29: DeprecationWarning: numpy.core.umath_tests is an internal NumPy module and should not be imported. It will be removed in a future NumPy release.
#   from numpy.core.umath_tests import inner1d

# %%
dtree = DecisionTreeClassifier()

# %%
dtree.fit(x_train, y_train)
# Out:
# DecisionTreeClassifier(class_weight=None, criterion='gini', max_depth=None,
#             max_features=None, max_leaf_nodes=None,
#             min_impurity_decrease=0.0, min_impurity_split=None,
#             min_samples_leaf=1, min_samples_split=2,
#             min_weight_fraction_leaf=0.0, presort=False, random_state=None,
#             splitter='best')

# %%
predTree = dtree.predict(x_test)

# %%
print(classification_report(y_test, predTree))
# Out:
#              precision    recall  f1-score   support
#
#           0       0.97      0.98      0.98      3178
#           1       0.54      0.49      0.52       161
#
# avg / total       0.95      0.96      0.95      3339

# %%
print(confusion_matrix(y_test, predTree))
# Out:
# [[3112   66]
#  [  82   79]]

# %%
rfc = RandomForestClassifier(n_estimators=200)

# %%
rfc.fit(x_train, y_train)
# Out:
# RandomForestClassifier(bootstrap=True, class_weight=None, criterion='gini',
#             max_depth=None, max_features='auto', max_leaf_nodes=None,
#             min_impurity_decrease=0.0, min_impurity_split=None,
#             min_samples_leaf=1, min_samples_split=2,
#             min_weight_fraction_leaf=0.0, n_estimators=200, n_jobs=1,
#             oob_score=False, random_state=None, verbose=0,
#             warm_start=False)

# %%
rfc_pred = rfc.predict(x_test)

# %%
print(classification_report(y_test, rfc_pred))
# Out:
#              precision    recall  f1-score   support
#
#           0       0.97      0.99      0.98      3178
#           1       0.64      0.49      0.55       161
#
# avg / total       0.96      0.96      0.96      3339

# %%
print(confusion_matrix(y_test, rfc_pred))
# Out:
# [[3133   45]
#  [  82   79]]

# %%
from sklearn.svm import SVC

# %%
svc = SVC()

# %%
svc.fit(x_train, y_train)
# Out:
# SVC(C=1.0, cache_size=200, class_weight=None, coef0=0.0,
#   decision_function_shape='ovr', degree=3, gamma='auto', kernel='rbf',
#   max_iter=-1, probability=False, random_state=None, shrinking=True,
#   tol=0.001, verbose=False)

# %%
svc_pred = svc.predict(x_test)

# %%
print(classification_report(y_test, svc_pred))
# Out:
#              precision    recall  f1-score   support
#
#           0       0.97      0.99      0.98      3178
#           1       0.74      0.30      0.43       161
#
# avg / total       0.96      0.96      0.95      3339

# %%
print(confusion_matrix(y_test, svc_pred))
# Out:
# [[3161   17]
#  [ 112   49]]

# %%
df2.drop(['Dia', 'Cartão'], axis=1, inplace=True)
hora_dia = []

for i in range(len(df2['Hora'])):
    hora_dia.append(df2['Hora'][i].hour)
    
df_teste2 = pd.DataFrame(hora_dia, columns=['Hora do Dia'])
df2 = pd.concat([df2, df_teste2], axis=1)
df2.drop(['Hora'], axis=1, inplace=True)

# %%
df2
# Out:
#          Valor  CBK  Dia da Semana  Hora do Dia
# 0       112.00  NaN              0            0
# 1       112.00  NaN              0            0
# 2        18.34  NaN              0            0
# 3        55.00  NaN              0            0
# 4        50.00  NaN              0            0
# 5        50.00  NaN              0            0
# 6        50.00  NaN              0            0
# 7        50.00  NaN              0            0
# 8       201.60  NaN              0            0
# 9       201.60  NaN              0            0
# 10      201.60  NaN              0            0
# 11       53.60  NaN              0            1
# 12      112.00  NaN              0            1
# 13       88.00  NaN              0            1
# 14      280.00  NaN              0            1
# 15      134.40  NaN              0            2
# 16     1100.00  NaN              0            8
# 17       88.00  NaN              0            8
# 18      115.00  NaN              0            9
# 19       15.00  NaN              0            9
# 20       89.60  NaN              0            9
# 21       89.60  NaN              0            9
# 22       24.00  NaN              0            9
# 23       89.60  NaN              0            9
# 24        5.00  NaN              0            9
# 25       35.00  NaN              0            9
# 26      182.69  NaN              0           10
# 27       15.00  NaN              0           10
# 28       99.00  NaN              0           10
# 29        5.00  NaN              0           10
# ...        ...  ...            ...          ...
# 11790    10.00  NaN              0           22
# 11791   122.55  NaN              0           22
# 11792     5.00  NaN              0           22
# 11793    80.50  NaN              0           22
# 11794    44.00  NaN              0           22
# 11795    44.00  NaN              0           22
# 11796    20.00  NaN              0           22
# 11797   103.50  NaN              0           22
# 11798   103.50  NaN              0           22
# 11799   103.50  NaN              0           22
# 11800    30.45  NaN              0           22
# 11801    40.85  NaN              0           22
# 11802    80.50  NaN              0           23
# 11803     5.00  NaN              0           23
# 11804    80.50  NaN              0           23
# 11805    15.00  NaN              0           23
# 11806   179.20  NaN              0           23
# 11807    89.60  NaN              0           23
# 11808    80.50  NaN              0           23
# 11809   403.20  NaN              0           23
# 11810   604.80  NaN              0           23
# 11811   207.00  NaN              0           23
# 11812    11.00  NaN              0           23
# 11813   120.00  NaN              0           23
# 11814    15.00  NaN              0           23
# 11815   161.00  NaN              0           23
# 11816   103.50  NaN              0           23
# 11817    60.89  NaN              0           23
# 11818    46.00  NaN              0           23
# 11819    77.00  NaN              0           23
#
# [11820 rows x 4 columns]

# %%
#Avaliação de quantos casos positivos de chargeback o modelo SVM retorna

svc_pred = svc.predict(df2[['Valor','Dia da Semana','Hora do Dia']])

contagem =  0 
for i in range(len(svc_pred)):
    if svc_pred[i] == 1:
        contagem +=1
        
contagem
# Out:
# 62

# %%
#Avaliação de quantos casos positivos de chargeback o modelo RandomForest retorna

contagem =  0 

rfc_pred = rfc.predict(df2[['Valor','Dia da Semana','Hora do Dia']])
contagem =  0 
for i in range(len(rfc_pred)):
    if rfc_pred[i] == 1:
        print(df.loc[i])
        contagem +=1
        
contagem
# Out:
# 164

# %%
#Avaliação de quantos casos positivos de chargeback o modelo DecisionTree retorna

contagem =  0 

predTree = dtree.predict(df2[['Valor','Dia da Semana','Hora do Dia']])
contagem =  0 
for i in range(len(predTree)):
    if predTree[i] == 1:
        contagem +=1
        
contagem
# Out:
# 356

# %%
#Avaliação de quantos casos positivos de chargeback o modelo LogisticRegresion retorna

contagem =  0 

predictions = logmodel.predict(df2[['Valor','Dia da Semana','Hora do Dia']])
contagem =  0 
for i in range(len(predictions)):
    if predictions[i] == 1:
        contagem +=1
        
contagem
# Out:
# 0

# %% [markdown]
# # Avalições finais

# %% [markdown]
# Otimizar recall ou precision? Otimizar o recall, pois o custo de tratar uma transação como chargeback, mesmo não sendo, é menor, do que não identificar uma transação como chargebak e depois descobrir que é.
#
# O modelo que apresentou melhor resultado foi o RandomForest, já que ele apresentou um melhor valor de recall, em comparação ao SVM.

# %%
#dataframe com a previsão das transações do tipo chargeback ou não, de acordo com o modelo de Random Forest.

df_pred = pd.DataFrame(rfc_pred, columns=['Chargeback'])
df_modelo = pd.read_excel('Dados - Desafio Stone.xlsx', sheet_name='Aba 2')
df_modelo = pd.concat([df_modelo, df_pred], axis=1)
df_modelo.drop(['CBK'], axis=1, inplace=True)
df_modelo
# Out:
#              Dia      Hora    Valor            Cartão  Chargeback
# 0     2015-06-01  00:02:25   112.00  541555******5965           0
# 1     2015-06-01  00:30:45   112.00  406669******7350           0
# 2     2015-06-01  00:43:20    18.34  541187******4535           0
# 3     2015-06-01  00:46:46    55.00  554927******5629           0
# 4     2015-06-01  00:47:50    50.00  498407******2077           0
# 5     2015-06-01  00:48:51    50.00  498407******2077           0
# 6     2015-06-01  00:49:55    50.00  498407******2077           0
# 7     2015-06-01  00:51:08    50.00  498407******2077           0
# 8     2015-06-01  00:53:28   201.60  498407******2077           1
# 9     2015-06-01  00:54:39   201.60  498407******2077           1
# 10    2015-06-01  00:55:33   201.60  498407******2077           1
# 11    2015-06-01  01:03:31    53.60  540105******5422           0
# 12    2015-06-01  01:18:46   112.00  515894******8424           0
# 13    2015-06-01  01:28:28    88.00  453211******9596           0
# 14    2015-06-01  01:45:59   280.00  490172******5444           0
# 15    2015-06-01  02:26:37   134.40  554927******7779           0
# 16    2015-06-01  08:04:11  1100.00  548293******5170           0
# 17    2015-06-01  08:26:23    88.00  525631******5400           0
# 18    2015-06-01  09:01:54   115.00  400970******8593           0
